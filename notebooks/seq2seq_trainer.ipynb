# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  raise EnvironmentError('This notebook should run on a GPU! Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, and then re-execute this cell.')
else:
  print(gpu_info)

# %%
if 'google.colab' in str(get_ipython()):
  from google.colab import drive
  drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install -r /content/drive/MyDrive/MARTIN/requirements.txt

# %%
# !python3 /content/drive/MyDrive/MARTIN/src/hf_transformer_trainer.py \
# --eval_steps 101 \
# --warmup_steps 10 \
# --pretrained_model_path /content/drive/MyDrive/MARTIN/models/transformer/_pretrained/seq2seq_bert2bert \
# --ds_path /content/drive/MyDrive/MARTIN/data/_collections/bert_finals/final_with_wiki_train \
# --save_model_path /content/drive/MyDrive/MARTIN/models/transformer/_fine_tuned/final_bert2bert_big \
# --training_output_path /content/drive/MyDrive/MARTIN/output/training/bert2bert_test_big_trained \
# --tokenizer_id bert-base-cased  \

# %%
# !python /content/drive/MyDrive/MARTIN/src/custom_transformer_trainer.py \
--ds_path /content/drive/MyDrive/MARTIN/data/_playground_data \
--train_file final_with_wiki_train.csv \
--test_file final_with_wiki_test.csv \
--epochs 2 \
--loss_plot_save_path /content/drive/MyDrive/testing_mode
# Out:
# 2021-07-04 07:17:51,015 - INFO - Creating dataset from /content/drive/MyDrive/MARTIN/data/_playground_data.
# 2021-07-04 07:17:51,234 - INFO - Training starting ...
# 2021-07-04 07:17:53,537 - INFO - ... training finished!
#             Loss
# Epoch
# 1      39.311964
# 2      36.389163

# %%
# !python /content/drive/MyDrive/MARTIN/src/custom_transformer_trainer.py \
--ds_path /content/drive/MyDrive/MARTIN/data/_collections \
--train_file final_with_wiki_train.csv \
--test_file final_with_wiki_test.csv \
--epochs 1 \
--loss_plot_save_path /content/drive/MyDrive/testing_mode
